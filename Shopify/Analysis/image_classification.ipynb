# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import sqlalchemy
from sqlalchemy import create_engine
import config
import datetime as dt
import re
import googletrans
from googletrans import Translator
from nltk import PorterStemmer
import inflection as inf
ps = PorterStemmer()
import os
from PIL import Image
import requests
from pathlib import Path
from io import BytesIO


import warnings
warnings.filterwarnings('ignore') 

pd.options.display.max_columns = 300
pd.options.display.max_rows = 300
pd.options.display.max_colwidth = 400

# %%
dbtype = config.database_new['dbtype']
user = config.database_new['user']
password = config.database_new['password']
ip = config.database_new['ip']
port = config.database_new['port']
name = config.database_new['name']

engine = create_engine(f'{dbtype}://{user}:{password}@{ip}:{port}/{name}')

# %% [markdown]
# ### Importing the dataset

# %%
query = """SELECT image, product_type FROM public.competitor_products"""

# %%
df = pd.read_sql_query(query, engine)

# %%
print(f'The shape of the Dataset is: {df.shape}')
# Out:
# The shape of the Dataset is: (22889, 2)

# %% [markdown]
# ### Planification

# %% [markdown]
# In this notebook we will organize a dataset that contains only product type and image for us to do a classification dataset.
# We don't know how well the articles are classified inside of shopify because the variable that they use is a text box open for whatever the store wants to put in there.
# Luckily, Zalando has a dataset that contains 60,000 classified pictures with 10 different classes, that is very useful for us to imputate some of the unknown classes in our dataset.

# %% [markdown]
# Since we are trying to classify the pictures, first we have to clean and group different product types

# %% [markdown]
# #### All the categories are in a certain language and we want to translate them to english, for this, we use the google translator module.

# %%
translator = Translator()

translations = {}
unique_elements = df['product_type'].unique()
for element in unique_elements:
    translations[element] = translator.translate(element).text

# %%
def replacing(x, maestro, df):
    for key in maestro:
        df[x] = df[x].str.replace(key, maestro[key])
        
def replace_rootwords(word, column, df):
    df.loc[df[column].str.contains(word), column] = word
    
def clean_word(word, column, df, clean_word):
    df.loc[df[column]==word, column] = clean_word

# %%
replacing('product_type', translations, df) #Translate all words to english

df['product_type'] = df['product_type'].str.lower() #lower all the words to avoid capitalized buckets

df['product_type'] = df['product_type'].apply(lambda x: ' '.join([inf.singularize(item) for item in x.split()])) #singularize words to group them all

word_list = ['sneaker', 't-shirt', 'sweatshirt', 'hoodie', 'dress'] #avoid single brand usage of the word for us to group in that category. Not going to use in all words to avoid unnecessary "overfitting"
for word in word_list:
    replace_rootwords(word, 'product_type', df)
    
df.loc[df['product_type'].str.contains('women')|df['product_type'].str.contains('woman'), 'product_type'] = df['product_type'].str.replace(' - ', '').str.replace(' women', '').str.replace('women ', '').str.replace('women', '').str.replace('woman', '')
df.loc[df['product_type'].str.contains('men')|df['product_type'].str.contains('man'), 'product_type'] = df['product_type'].str.replace(' - ', '').str.replace(' men', '').str.replace('men ', '').str.replace(' man', '').str.replace('man ', '')
df.loc[df['product_type'].str.contains('unisex'), 'product_type'] = df['product_type'].str.replace(' - ', '').str.replace('unisex', '')

dirty_t = ['tshirt', 't shirt', 'tee-shirt', 'tee', 'tee shirt']
for word in dirty_t:
    clean_word(word, 'product_type', df, 't-shirt')
dirty_sweat = ['sweat', 'sweatmen']
for word in dirty_sweat:
    clean_word(word, 'product_type', df, 'sweatshirt')

# %%
df['product_type'].value_counts()
# Out:
# sneaker                                          7506
# t-shirt                                          2217
# sweatshirt                                        913
# shoe                                              684
# shirt                                             671
# sweater                                           529
# dress                                             503
# bottom                                            431
# hoodie                                            414
# sandal                                            395
# boot                                              383
# jumper                                            349
# pant                                              328
# footwear                                          328
# outerwear                                         274
# high-heeled sandal                                265
#                                                   253
# top                                               225
# short                                             217
# accessory                                         193
# legging                                           182
# jersey                                            172
# knit top                                          168
# hoody                                             166
# one-piece swimsuit                                152
# woven top                                         141
# high platform                                     137
# sport bra                                         135
# jacket                                            131
# espadrille                                        129
# skirt                                             110
# boot and ankle boot                               105
# materium magnetic                                 102
# knitwear                                           94
# booty                                              89
# crop top                                           85
# underwear                                          81
# gift card                                          80
# freebie                                            78
# polo                                               76
# atom oasi                                          72
# swim                                               72
# world                                              71
# all over print                                     69
# blazer                                             66
# tank                                               65
# intimate                                           64
# medium platform                                    63
# custom                                             62
# marathon origin                                    60
# marathon nebula                                    60
# blouse                                             59
# exterior                                           56
# low platform                                       56
# american                                           55
# trouser                                            52
# long sleeve top                                    51
# sock                                               49
# materium easy                                      48
# materium olimpium                                  48
# materium stone                                     48
# mule                                               47
# pique                                              45
# boxer                                              44
# knit                                               42
# cap                                                38
# slipper                                            38
# invited brand / footwear - karhu                   38
# lunar pulse                                        36
# atom eternal v2                                    36
# startup                                            36
# marathon skin                                      36
# phoenix air                                        36
# atom mist                                          36
# hybrid                                             36
# anatomical                                         36
# solar rocket                                       36
# alaska                                             36
# marathon odyssey                                   36
# marathon boat                                      36
# hybrid asteroid                                    36
# outer garment                                      35
# erosion moss                                       34
# materium density                                   33
# atom gravity                                       30
# other                                              30
# accessory de piel                                  30
# pullover                                           30
# army                                               29
# mobile case                                        28
# sandalium plana                                    28
# heel                                               28
# pump                                               28
# denim                                              27
# bag                                                27
# belt                                               25
# chroma glass                                       24
# atom boot                                          24
# hybrid stereo                                      24
# jumpsuit                                           24
# chroma glass                                       24
# loafer                                             20
# flat shoe                                          20
# imitation jewelry                                  19
# tie                                                19
# swimsuit                                           19
# polar                                              18
# mazzu glass                                        18
# shelter                                            18
# invited brand / jeans - edwin                      18
# solar meteora                                      18
# mazzu glass                                        18
# marathon sigma                                     18
# helmet                                             17
# match                                              16
# suit                                               16
# all                                                16
# baselayer                                          16
# tokyo                                              16
# invited brand / outerwear - holubar                15
# vest                                               15
# hats&bag                                           13
# alpha carbono                                      13
# marathon                                           12
# thing                                              12
# swimsuit top                                       12
# marketing                                          12
# invited brand / outerwear - bellerose              12
# journey                                            12
# materium boot                                      12
# proxy                                              12
# toy                                                12
# juno cloud                                         12
# handbag                                            11
# metal glass                                        10
# metal glass                                        10
# invited brand / footwear - artifact & superga      10
# trouser denim                                      10
# invited brand / gadget - lexon                      9
# two-piece swimsuit                                  9
# cardigan                                            9
# kid boy glass                                       8
# invited brand / polo - bellerose                    8
# kid girl glass                                      8
# invited brands/jackets-bellerose                    8
# zero                                                8
# beach                                               8
# invited brand / shirt - bellerose                   8
# flat                                                8
# pl                                                  7
# scarf                                               7
# glass                                               7
# basic                                               6
# juno nova                                           6
# invited brand / footwear - new balance              6
# mask                                                5
# invited brand / gadget - kreafunk                   5
# bundle                                              5
# hoody and jacket                                    5
# one-piece swimsuit - aop                            5
# swimwear                                            5
# round shoelace                                      5
# invited brand / footwear - autry                    4
# earring                                             4
# hat                                                 4
# backpack                                            4
# pashmina                                            4
# beany                                               4
# pocket                                              4
# invited brand / pant - bellerose                    4
# ty                                                  4
# wallet                                              4
# bikini                                              4
# ski goggle                                          4
# block                                               3
# clip-on chroma                                      3
# flat lace                                           3
# clip-on mazzu                                       3
# container suite                                     3
# clip-on mazzu                                       3
# ring                                                3
# clip-on chroma                                      3
# sunglass                                            3
# invited brand / gadget - lomography                 3
# lace                                                3
# light outerwear                                     3
# bucket bag                                          3
# chain                                               2
# bottle                                              2
# bracelet                                            2
# - magazine                                          2
# book and magazine                                   2
# invited brand / accessory - filson                  2
# clutch                                              2
# candle                                              1
# glofe                                               1
# invited brand / magazine - openhouse                1
# marbled lace                                        1
# wrapin                                              1
# invited brand / book - gestalten                    1
# purse                                               1
# sack                                                1
# carbon offset                                       1
# molescow                                            1
# preset                                              1
# totebag                                             1
# tote bag                                            1
# pack                                                1
# prescription                                        1
# invited brand                                       1
# necklace                                            1
# Name: product_type, dtype: int64

# %% [markdown]
# Now let's right a little bit of code that downloads every image of the dataset so that we have it in local.
# I'm really new at image storing so I will store them all in a folder called images and then maybe will optimize the storing of the images.
# I'll show two ways to store images, one in the same dataframe with ByteIO

# %% [markdown]
# #### Dataframe saved images

# %%
Using a web user agent we can request all the images and save them with BytesIo library in the same dataframe. The issue with this

# %%
pictures = [None] * df.shape[0]

df.insert(df.shape[1], "pictures", pictures, True)

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/xxx.xx (KHTML, like Gecko) Chrome/xx.x.xxxx.xxx Safari/xxx.xx'}

for i in range(df.shape[0]):
    r = requests.get(df.iloc[i,0], headers=headers)
    r.raise_for_status()
    df.iloc[i,2] = Image.open(BytesIO(r.content))

# %%
df['filename'] = df.index.astype('string') + '.jpg'

# %%
# Out:
#                                                                                                                                                           image  \
# 4683   https://cdn.shopify.com/s/files/1/0003/6270/9002/products/TSHIRT_NOT_WELCOME_GREY_008_03_FULLRES_1_67093bd4-552d-4f17-b0ed-6d3f91cfeb12.jpg?v=1573129967
# 6768                                                           https://cdn.shopify.com/s/files/1/1514/1888/products/The_Brubaker_23-1-20112969.jpg?v=1592839138
# 10820                                                    https://cdn.shopify.com/s/files/1/0251/4544/2350/products/zapatillas-mujer-mayfair-05.jpg?v=1598615762
# 8181                                         https://cdn.shopify.com/s/files/1/0037/8925/8841/products/17_d699f47c-111d-4eb4-8fb5-5d56db2405b5.jpg?v=1582144753
# 3359                                                         https://cdn.shopify.com/s/files/1/0122/2724/8185/products/OBEX_BC_SPIN_AVIP_RIGHT.jpg?v=1574068457
# ...                                                                                                                                                         ...
# 21420                                    https://cdn.shopify.com/s/files/1/1846/7645/products/mim-shoes-sandalia-cerdena-dorado-11950909816926.jpg?v=1579066791
# 16201                                                  https://cdn.shopify.com/s/files/1/0251/4544/2350/products/zapatillas-nino-vienna-kids-5.jpg?v=1598619398
# 14540                                                    https://cdn.shopify.com/s/files/1/0251/4544/2350/products/zapatillas-mujer-new-york-5.jpg?v=1598618621
# 8748                       https://cdn.shopify.com/s/files/1/0209/1522/products/hoodies-macaroni-hoodie-2_7a44097f-85e6-41e0-9bf8-4988eb2edb3e.jpg?v=1601506358
# 2188                                                            https://cdn.shopify.com/s/files/1/0035/7947/8083/products/grandmother-cap-navy.png?v=1582286263
#
#              product_type  \
# 4683              t-shirt
# 6768             american
# 10820             sneaker
# 8181             jumpsuit
# 3359               helmet
# ...                   ...
# 21420  high-heeled sandal
# 16201             sneaker
# 14540             sneaker
# 8748                hoody
# 2188                  cap
#
#                                                                                  pictures  \
# 4683   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2000x2000 at 0x1CBD0BA4EC8>
# 6768   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1333x2000 at 0x1CBD0CF5788>
# 10820  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1500x1995 at 0x1CBD0C4FF08>
# 8181   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x2880 at 0x1CBD0BA48C8>
# 3359   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x2500 at 0x1CBD0CF5A48>
# ...                                                                                   ...
# 21420                                                                                None
# 16201                                                                                None
# 14540                                                                                None
# 8748                                                                                 None
# 2188                                                                                 None
#
#         filename
# 4683    4683.jpg
# 6768    6768.jpg
# 10820  10820.jpg
# 8181    8181.jpg
# 3359    3359.jpg
# ...          ...
# 21420  21420.jpg
# 16201  16201.jpg
# 14540  14540.jpg
# 8748    8748.jpg
# 2188    2188.jpg
#
# [1000 rows x 4 columns]

# %%
pictures = [None] * df.shape[0]

df.insert(df.shape[1], "pictures", pictures, True)

headers = {agent}

for i in range(df.shape[0]):
    r = requests.get(df.iloc[i,0], headers=headers)
    r.raise_for_status()
    df.iloc[i,2] = Image.open(BytesIO(r.content))
# Out:
#                                                                                                              image  \
# 0                          https://cdn.shopify.com/s/files/1/0015/0942/5197/products/26048-PINK-3.jpg?v=1604060161
# 1                          https://cdn.shopify.com/s/files/1/0015/0942/5197/products/26048-PINK-3.jpg?v=1604060161
# 2                          https://cdn.shopify.com/s/files/1/0015/0942/5197/products/26048-PINK-3.jpg?v=1604060161
# 3                          https://cdn.shopify.com/s/files/1/0015/0942/5197/products/26048-PINK-3.jpg?v=1604060161
# 4                         https://cdn.shopify.com/s/files/1/0015/0942/5197/products/24933-BEIGE-3.jpg?v=1604055392
# ...                                                                                                            ...
# 22884  https://cdn.shopify.com/s/files/1/0762/7039/products/back-strap-camel-sandal-alohas-138384.jpg?v=1578543593
# 22885  https://cdn.shopify.com/s/files/1/0762/7039/products/back-strap-camel-sandal-alohas-138384.jpg?v=1578543593
# 22886  https://cdn.shopify.com/s/files/1/0762/7039/products/back-strap-camel-sandal-alohas-138384.jpg?v=1578543593
# 22887  https://cdn.shopify.com/s/files/1/0762/7039/products/back-strap-camel-sandal-alohas-138384.jpg?v=1578543593
# 22888  https://cdn.shopify.com/s/files/1/0762/7039/products/back-strap-camel-sandal-alohas-138384.jpg?v=1578543593
#
#       product_type   filename
# 0           blazer      0.jpg
# 1           blazer      1.jpg
# 2           blazer      2.jpg
# 3           blazer      3.jpg
# 4              cap      4.jpg
# ...            ...        ...
# 22884       sandal  22884.jpg
# 22885       sandal  22885.jpg
# 22886       sandal  22886.jpg
# 22887       sandal  22887.jpg
# 22888       sandal  22888.jpg
#
# [22889 rows x 3 columns]
